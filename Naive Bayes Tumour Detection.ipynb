# %%
import pandas as pd 
import numpy as np

import scipy.stats as s

# %%
rawdata = pd.read_csv("data.csv")

# %%
rawdata.head()
# Out:
#          id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0    842302         M        17.99         10.38          122.80     1001.0
# 1    842517         M        20.57         17.77          132.90     1326.0
# 2  84300903         M        19.69         21.25          130.00     1203.0
# 3  84348301         M        11.42         20.38           77.58      386.1
# 4  84358402         M        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
# ...

# %% [markdown]
# It is a thumb rule that 70% data should be training data and 30% data should be testing data.

# %%
training_data = int(len(rawdata)*0.70)

# %%
training_data
# Out:
# 398

# %%
testing_data = len(rawdata) - training_data

# %%
testing_data
# Out:
# 171

# %%
malignant = pd.DataFrame(rawdata[rawdata['diagnosis']=='M'])

# %%
malignant
# Out:
#             id diagnosis  radius_mean  texture_mean  perimeter_mean  \
# 0       842302         M        17.99         10.38          122.80
# 1       842517         M        20.57         17.77          132.90
# 2     84300903         M        19.69         21.25          130.00
# 3     84348301         M        11.42         20.38           77.58
# 4     84358402         M        20.29         14.34          135.10
# 5       843786         M        12.45         15.70           82.57
# 6       844359         M        18.25         19.98          119.60
# 7     84458202         M        13.71         20.83           90.20
# 8       844981         M        13.00         21.82           87.50
# 9     84501001         M        12.46         24.04           83.97
# 10      845636         M        16.02         23.24          102.70
# 11    84610002         M        15.78         17.89          103.60
# 12      846226         M        19.17         24.80          132.40
# ...

# %%
malignant_training_data = malignant.iloc[0:199]
malignant_training_data = malignant_training_data['radius_mean']

# %%
malignant_training_data
# Out:
# 0      17.99
# 1      20.57
# 2      19.69
# 3      11.42
# 4      20.29
# 5      12.45
# 6      18.25
# 7      13.71
# 8      13.00
# 9      12.46
# 10     16.02
# 11     15.78
# 12     19.17
# 13     15.85
# 14     13.73
# 15     14.54
# 16     14.68
# 17     16.13
# 18     19.81
# 22     15.34
# 23     21.16
# 24     16.65
# 25     17.14
# 26     14.58
# 27     18.61
# 28     15.30
# 29     17.57
# 30     18.63
# 31     11.84
# 32     17.02
#        ...
# 385    14.60
# 389    19.55
# 392    15.49
# 393    21.61
# 400    17.91
# 408    17.99
# 414    15.13
# 417    15.50
# 430    14.90
# 432    20.18
# 433    18.82
# 435    13.98
# 441    17.27
# 444    18.03
# 446    17.75
# 449    21.10
# 451    19.59
# 460    17.08
# 461    27.42
# 468    17.60
# 479    16.25
# 487    19.44
# 489    16.69
# 492    18.01
# 498    18.49
# 499    20.59
# 501    13.82
# 503    23.09
# 509    15.46
# 512    13.40
# Name: radius_mean, Length: 199, dtype: float64

# %%
malignant_testing_data = malignant.iloc[199:]
malignant_testing_data = pd.DataFrame(malignant_testing_data['radius_mean'])

# %%
malignant_testing_data
# Out:
#      radius_mean
# 514        15.05
# 516        18.31
# 517        19.89
# 521        24.63
# 533        20.47
# 535        20.55
# 536        14.27
# 562        15.22
# 563        20.92
# 564        21.56
# 565        20.13
# 566        16.60
# 567        20.60

# %%
benign = pd.DataFrame(rawdata[rawdata['diagnosis']=='B'])

# %%
benign
# Out:
#            id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 19    8510426         B       13.540         14.36           87.46      566.3
# 20    8510653         B       13.080         15.71           85.63      520.0
# 21    8510824         B        9.504         12.44           60.34      273.9
# 37     854941         B       13.030         18.42           82.61      523.8
# 46   85713702         B        8.196         16.84           51.71      201.9
# 48     857155         B       12.050         14.63           78.04      449.3
# 49     857156         B       13.490         22.30           86.91      561.0
# 50     857343         B       11.760         21.60           74.72      427.9
# 51     857373         B       13.640         16.34           87.21      571.8
# 52     857374         B       11.940         18.24           75.71      437.6
# 55   85759902         B       11.520         18.75           73.34      409.0
# ...

# %%
benign_training_data = benign.iloc[0:199]
benign_training_data = benign_training_data['radius_mean']

# %%
benign_training_data
# Out:
# 19     13.540
# 20     13.080
# 21      9.504
# 37     13.030
# 46      8.196
# 48     12.050
# 49     13.490
# 50     11.760
# 51     13.640
# 52     11.940
# 55     11.520
# 58     13.050
# 59      8.618
# 60     10.170
# 61      8.598
# 63      9.173
# 66      9.465
# 67     11.310
# 68      9.029
# 69     12.780
# 71      8.888
# 74     12.310
# 76     13.530
# 79     12.860
# 80     11.450
# 81     13.340
# 84     12.000
# 88     12.360
# 89     14.640
# 90     14.620
#         ...
# 318     9.042
# 319    12.430
# 320    10.250
# 322    12.860
# 324    12.200
# 325    12.670
# 326    14.110
# 327    12.030
# 331    12.980
# 332    11.220
# 333    11.250
# 334    12.300
# 336    12.990
# 338    10.050
# 340    14.420
# 341     9.606
# 342    11.060
# 344    11.710
# 345    10.260
# 346    12.060
# 347    14.760
# 348    11.470
# 349    11.950
# 350    11.660
# 354    11.140
# 355    12.560
# 356    13.050
# 357    13.870
# 358     8.878
# 359     9.436
# ...

# %%
benign_testing_data = benign.iloc[199:]
benign_testing_data = pd.DataFrame(benign_testing_data['radius_mean'])

# %%
benign_testing_data
# Out:
#      radius_mean
# 360       12.540
# 361       13.300
# 362       12.760
# 363       16.500
# 364       13.400
# 367       12.210
# 371       15.190
# 374       13.690
# 375       16.170
# 376       10.570
# 377       13.460
# 378       13.660
# 380       11.270
# 381       11.040
# 382       12.050
# 383       12.390
# 384       13.280
# 386       12.210
# 387       13.880
# 388       11.270
# 390       10.260
# 391        8.734
# 394       12.100
# 395       14.060
# 396       13.510
# 397       12.800
# 398       11.060
# 399       11.800
# 401       11.930
# 402       12.960
# ..           ...
# 530       11.750
# 531       11.670
# 532       13.680
# 534       10.960
# 537       11.690
# 538        7.729
# 539        7.691
# 540       11.540
# 541       14.470
# 542       14.740
# 543       13.210
# 544       13.870
# 545       13.620
# 546       10.320
# 547       10.260
# 548        9.683
# 549       10.820
# 550       10.860
# 551       11.130
# 552       12.770
# ...

# %%
mu_cap_m_radius_mean = malignant_training_data.mean()

# %%
sigma_cap_m_radius_mean = malignant_training_data.std()

# %%
mu_cap_b_radius_mean = benign_training_data.mean()

# %%
sigma_cap_b_radius_mean = benign_training_data.std()

# %%
precision_sum = 0
recall_sum = 0 
accuracy_sum = 0 

for i in range(0,len(malignant_testing_data)):
    class_conditional_benign = s.norm.pdf(malignant_testing_data.iloc[i],mu_cap_b_radius_mean,sigma_cap_b_radius_mean)
    
    class_conditional_malignant = s.norm.pdf(malignant_testing_data.iloc[i],mu_cap_m_radius_mean,sigma_cap_m_radius_mean)
    
    posterior_benign_prob = (class_conditional_benign)/(class_conditional_benign + class_conditional_malignant)
    
    posterior_malignant_prob = 1 - posterior_benign_prob
    
    if posterior_benign_prob < 0.5:
        accuracy_sum += 1

# %%
accuracy_sum
# Out:
# 12

# %%
for i in range(0,len(benign_testing_data)):
    class_conditional_benign = s.norm.pdf(benign_testing_data.iloc[i],mu_cap_b_radius_mean,sigma_cap_b_radius_mean)
    
    class_conditional_malignant = s.norm.pdf(benign_testing_data.iloc[i],mu_cap_m_radius_mean,sigma_cap_m_radius_mean)
    
    posterior_benign_prob = (class_conditional_benign)/(class_conditional_benign + class_conditional_malignant)
    
    posterior_malignant_prob = 1 - posterior_benign_prob
    
    if posterior_benign_prob > 0.5:
        accuracy_sum += 1

# %%
accuracy_sum
# Out:
# 148

# %%
(148/171)*100
# Out:
# 86.54970760233918
